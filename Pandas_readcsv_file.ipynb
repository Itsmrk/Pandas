# %%
import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv")

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df[4:9]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
#
#    Mobile Games hrs  Percantege
# 4                 0          75
# 5                 0          96
# 6                 0          80
# 7                 0          90
# 8                 4          60

# %%
pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\demodata_series.csv")
# Out:
#                 IT Companies
# 0                        TCS
# 1                    Infosys
# 2              Tech Mahindra
# 3                      Wipro
# 4           HCL Technologies
# 5               L&T Infotech
# 6                   Mindtree
# 7                    Mphasis
# 8  Oracle Financial Services
# 9                Rotla India

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\IT's MRK\Desktop\Learning\Pandas

# %% [markdown]
# ## write csv file in pandas

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv")
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percantege'],
#       dtype='object')

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , nrows = 1)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percantege
# 0                 5          50

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , nrows = 5)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df[0:4] # specific rows selection
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , usecols = [1] )
df
# Out:
#    Class
# 0     10
# 1     10
# 2     10
# 3     11
# 4     11
# 5     11
# 6     12
# 7     12
# 8     12
# 9     12

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , usecols = [1,3] )
df
# Out:
#    Class  Sleeping hrs
# 0     10             9
# 1     10             8
# 2     10             8
# 3     11            10
# 4     11             7
# 5     11             7
# 6     12             6
# 7     12             6
# 8     12             8
# 9     12             9

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , skiprows = 1 )
df
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , skiprows = 2 )
df
# Out:
#    1002  10   6   8  2  0  80
# 0  1003  10   3   8  2  4  60
# 1  1004  11   0  10  1  5  45
# 2  1005  11   4   7  2  0  75
# 3  1006  11  10   7  0  0  96
# 4  1007  12   4   6  0  0  80
# 5  1008  12  10   6  2  0  90
# 6  1009  12   2   8  2  4  60
# 7  1010  12   6   9  1  0  85

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , skiprows = [4] )
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1005     11          4             7                       2
# 4        1006     11         10             7                       0
# 5        1007     12          4             6                       0
# 6        1008     12         10             6                       2
# 7        1009     12          2             8                       2
# 8        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 0          75
# 4                 0          96
# 5                 0          80
# 6                 0          90
# ...

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , skiprows = [2,4,5,1] )
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1003     10          3             8                       2
# 1        1006     11         10             7                       0
# 2        1007     12          4             6                       0
# 3        1008     12         10             6                       2
# 4        1009     12          2             8                       2
# 5        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 4          60
# 1                 0          96
# 2                 0          80
# 3                 0          90
# 4                 4          60
# 5                 0          85

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , index_col="Student ID" )
df
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , index_col="Class" )
df
# Out:
#        Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10           1001          2             9                       3
# 10           1002          6             8                       2
# 10           1003          3             8                       2
# 11           1004          0            10                       1
# 11           1005          4             7                       2
# 11           1006         10             7                       0
# 12           1007          4             6                       0
# 12           1008         10             6                       2
# 12           1009          2             8                       2
# 12           1010          6             9                       1
#
#        Mobile Games hrs  Percantege
# Class
# 10                    5          50
# 10                    0          80
# 10                    4          60
# 11                    5          45
# ...

# %%
df = pd.read_csv("C:\\Users\IT's MRK\Desktop\Learning\Pandas\student_results.csv" , index_col= 0 )
df
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...
